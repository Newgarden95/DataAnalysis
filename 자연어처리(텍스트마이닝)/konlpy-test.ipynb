# %% [markdown]
# # 한글 자연어 처리(NL)

# %%
from konlpy.tag import Okt

# %%
t = Okt() #Okt()라는 객체 생성

# %%
#뉴스 기사 분석할 때, t.nouns(크롤링한 내용 넣기)
#토큰 : 끊어주는 단위
tokens_ko = t.nouns("나는 가방에 들어갈거야..가방..가방...진짜야..진짜..진짜..진짜..진짜..오늘은 수요일이야..오늘")
tokens_ko
# Out:
# ['나', '가방', '가방', '가방', '진짜', '진짜', '진짜', '진짜', '진짜', '오늘', '수요일', '오늘']

# %%
import nltk
ko = nltk.Text(tokens_ko, name='test')

# %%
#한글 사용을 위한 설정
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도
 
# %config InlineBackend.figure_format = 'retina'

# %%
#한글 사용을 위한 설정
import matplotlib.font_manager as fm
fontpath = 'C:/ProgramData/Anaconda3/Lib/site-packages/pytagcloud/fonts/NanumGothic.ttf'

font_name = fm.FontProperties(fname=fontpath, size=9).get_name()
plt.rc('font', family=font_name)

# %%
fm._rebuild() #폰트 설정 반영

# %%
plt.figure(figsize=(10, 5))
ko.plot(50)
plt.show()

# %%
#str 설정하기  """ """ 큰,작은 따옴표 3개 
musk = """머스크 변심에 비트코인 폭락 "테슬라 코인 결제 중단"
[중앙일보] 입력 2021.05.13 08:05 수정 2021.05.13 11:01인쇄기사 보관함(스크랩)글자 작게글자 크게
기자
오원석 기자 사진오원석 기자
SNS 공유 및 댓글
SNS 클릭 수47
카카오톡
페이스북
트위터
카카오스토리
SNS 공유 더보기
일론 머스크 테슬라 최고경영자(CEO). 로이터=연합뉴스
일론 머스크 테슬라 최고경영자(CEO). 로이터=연합뉴스

미국 전기차업체 테슬라의 최고경영자(CEO)인 일론 머스크의 말 한마디에 암호화폐 시장이 출렁이고 있다. 머스크가 돌연 테슬라의 비트코인 결제를 중단한다고 12일(현지시간) 선언하면서 비트코인 가격이 폭락했다. 테슬라 전기차 구입에 비트코인 결제를 허용한 지 불과 두 달 만에 이를 번복했다.
 
머스크 CEO는 이날 자신의 트위터에서 "테슬라는 비트코인으로 자동차를 구입하도록 한 것을 잠정 중단했다"라며 그 이유로는 "비트코인 채굴과 거래에 화석연료, 특히 석탄의 사용이 급격하게 증가하고 있기 때문"이라고 덧붙였다.
 
이어 "암호화폐는 많은 영역에서 좋은 아이디어이고, 미래가 유망하다는 점을 믿는다"라면서도 "그러나 환경에는 좋지 않다"고 부연했다.
 
아울러 머스크 CEO는 "테슬라는 비트코인 채굴에 지속가능한 에너지가 사용될 때 까지 전기차 결제를 중단한다"라며 "비트코인 채굴에 사용되는 에너지의 1% 이하를 사용하는 다른 암호화폐를 찾고 있다"고 했다.
일론 머스크 테슬라 CEO가 비트코인 결제를 중단한다고 12일(현지시간) 발표했다. [트위터 캡처]
일론 머스크 테슬라 CEO가 비트코인 결제를 중단한다고 12일(현지시간) 발표했다. [트위터 캡처]

 
실제로 비트코인 채굴에는 많은 전기가 쓰인다. 지난 2월에는 비트코인 채굴에 아르헨티나의 연간 전기 사용량보다 더 많은 전력이 사용된다는 케임브리지대의 연구 결과도 나왔다. 화석연료로 생산한 전기를 활용해 비트코인을 만들어내는 과정이 기후에는 나쁜 영향을 끼치는 셈이다. 전기차 업체의 CEO로 그동안 기후문제와 친환경 경영에 관심을 기울인 머스크 CEO가 비트코인의 화석연료 문제에 부담을 느낀 것 아니냐는 분석이 나오는 대목이다.
 
머스크 CEO의 기습 트윗이 나온 직후 비트코인 가격이 급락했다. 국내 최대 거래소 업비트 기준 비트코인 가격은 머스크 CEO의 발표가 있기 전 6900만원대였으나, 트윗이 나온 직후 5% 이상 급락한 6550만원 초반대에서 거래 중이다.
 
그동안 머스크 CEO는 암호화폐와 관련한 발언을 공개적으로 쏟아냈다. 스스로를 '도지파더'(도지코인의 아버지)라고 부르는 그는 지난 8일 미 NBC 방송 간판 코미디 프로그램 '새터데이 나이트 라이브'(SNL)에 진행자로 출연해 도지코인을 언급했다. 머스크 CEO의 방송 출연을 전후로 도지코인의 가격이 위아래로 출렁이기도 했다.
 
오원석 기자 oh.wonseok@joongang.co.kr


[출처: 중앙일보] 머스크 변심에 비트코인 폭락 "테슬라 코인 결제 중단" """

# %%
#위의 기사에 대한 단어 추출
tokens_musk = t.nouns(musk)
tokens_musk
# Out:
# ['머스크',
#  '변심',
#  '비트코인',
#  '폭락',
#  '테슬라',
#  '코인',
#  '결제',
#  '중단',
#  '중앙',
#  '일보',
#  '입력',
#  '수정',
#  '인쇄',
#  '기사',
#  '보관',
#  '함',
#  '스크랩',
#  '글자',
#  '글자',
#  '크게',
#  '기자',
#  '석',
#  '기자',
#  '사진',
#  '오원',
#  '석',
#  '기자',
#  '공유',
#  '및',
#  '댓글',
#  '클릭',
#  '수',
#  '카카오',
#  '톡',
#  '페이스북',
#  '트위터',
#  '카카오스토리',
#  '공유',
#  '더',
#  '보기',
#  '론',
#  '머스크',
#  '테슬라',
#  '최고경영자',
#  '로이터',
#  '연합뉴스',
#  '론',
#  '머스크',
#  '테슬라',
#  '최고경영자',
#  '로이터',
#  '연합뉴스',
#  '미국',
#  '전기차',
#  '업체',
#  '테슬라',
#  '최고경영자',
#  '인',
#  '론',
#  '머스크',
#  '말',
#  '한마디',
#  '암호',
#  '화폐',
#  '시장',
#  '머스크',
#  '돌연',
#  '테슬라',
#  '비트코인',
#  '결제',
#  '중단',
#  '현지',
#  '시간',
#  '선언',
#  '비트코인',
#  '가격',
#  '폭락',
#  '테슬라',
#  '전기차',
#  '구입',
#  '비트코인',
#  '결제',
#  '허용',
#  '불과',
#  '두',
#  '달',
#  '번복',
#  '머스크',
#  '날',
#  '자신',
#  '트위터',
#  '테슬라',
#  '비트코인',
#  '자동차',
#  '구입',
#  '것',
#  '잠정',
#  '중단',
#  '라며',
#  '그',
#  '이유',
#  '비트코인',
#  '채굴',
#  '거래',
#  '화석연료',
#  '석탄',
#  '사용',
#  '증가',
#  '때문',
#  '암호',
#  '화폐',
#  '영역',
#  '아이디어',
#  '미래',
#  '유망',
#  '점',
#  '환경',
#  '고',
#  '부연',
#  '머스크',
#  '테슬라',
#  '비트코인',
#  '채굴',
#  '지속',
#  '에너지',
#  '사용',
#  '때',
#  '전기차',
#  '결제',
#  '중단',
#  '라며',
#  '비트코인',
#  '채굴',
#  '사용',
#  '에너지',
#  '이하',
#  '사용',
#  '다른',
#  '암호',
#  '화폐',
#  '고',
#  '론',
#  '머스크',
#  '테슬라',
#  '비트코인',
#  '결제',
#  '중단',
#  '현지',
#  '시간',
#  '발표',
#  '트위터',
#  '캡처',
#  '론',
#  '머스크',
#  '테슬라',
#  '비트코인',
#  '결제',
#  '중단',
#  '현지',
#  '시간',
#  '발표',
#  '트위터',
#  '캡처',
#  '실제',
#  '비트코인',
#  '채굴',
#  '전기',
#  '지난',
#  '비트코인',
#  '채굴',
#  '아르헨티나',
#  '연간',
#  '전기',
#  '용량',
#  '더',
#  '전력',
#  '사용',
#  '케임브리지대',
#  '연구',
#  '결과',
#  '화석연료',
#  '생산',
#  '전기',
#  '활용',
#  '비트코인',
#  '과정',
#  '기후',
#  '영향',
#  '셈',
#  '전기차',
#  '업체',
#  '로',
#  '그동안',
#  '기후',
#  '문제',
#  '친환경',
#  '경영',
#  '관심',
#  '머스크',
#  '비트코인',
#  '화석연료',
#  '문제',
#  '부담',
#  '것',
#  '분석',
#  '대목',
#  '머스크',
#  '의',
#  '기습',
#  '트윗',
#  '직후',
#  '비트코인',
#  '가격',
#  '급락',
#  '국내',
#  '최대',
#  '거래소',
#  '업',
#  '비트',
#  '기준',
#  '비트코인',
#  '가격',
#  '머스크',
#  '의',
#  '발표',
#  '전',
#  '트윗',
#  '직후',
#  '이상',
#  '급락',
#  '초반',
#  '거래',
#  '중이',
#  '그동안',
#  '머스크',
#  '암호',
#  '화폐',
#  '관련',
#  '발언',
#  '공개',
#  '스스로',
#  '도지',
#  '도지',
#  '코인',
#  '아버지',
#  '그',
#  '지난',
#  '방송',
#  '간판',
#  '코미디',
#  '프로그램',
#  '새터데이',
#  '나이트',
#  '라이브',
#  '진행자',
#  '출연',
#  '도지',
#  '코인',
#  '언급',
#  '머스크',
#  '의',
#  '방송',
#  '출연',
#  '전후',
#  '도지',
#  '코인',
#  '가격',
#  '위아래',
#  '기도',
#  '석',
#  '기자',
#  '출처',
#  '중앙',
#  '일보',
#  '머스크',
#  '변심',
#  '비트코인',
#  '폭락',
#  '테슬라',
#  '코인',
#  '결제',
#  '중단']

# %%
#말뭉치 만들기
musk_ko = nltk.Text(tokens_musk, name='test')
# Out:
# <Text: test>

# %%
plt.figure(figsize=(20, 10))
musk_ko.plot(50)
plt.show()

# %%
# -*- coding: utf-8 -*-
#워드클라우드 만들기
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%ED%81%AC%EB%A6%AC%EC%8A%A4%ED%95%80%20%ED%94%84%EB%A6%AC%EB%A8%BC
# https://namu.wiki/w/%EA%B9%80%EB%82%98%EB%9D%BC
# https://namu.wiki/w/%ED%97%88%EC%88%98(%ED%94%84%EB%A1%9C%EA%B2%8C%EC%9D%B4%EB%A8%B8)
# https://namu.wiki/w/%EB%8F%84%EC%A7%80%EC%BD%94%EC%9D%B8
# https://namu.wiki/w/%EB%8F%84%EB%82%A0%EB%93%9C%20%EB%8D%95%20%EA%B0%80%EC%A1%B1%EC%9D%98%20%EB%AA%A8%ED%97%98/%EB%93%B1%EC%9E%A5%EC%9D%B8%EB%AC%BC

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list) #스트링 만들기

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 크리스핀 프리먼
#
#
# 미국의 남성 성우/ㅋ1972년 출생일리노이 주 출신 인물1997년 데뷔유대계 미국인
#
#
# 크리스핀 프리먼Crispin Freeman이름크리스핀 맥두걸 프리먼(Crispin McDougal Freeman)출생1972년 2월 9일 (49세)미국 일리노이 주 시카고국적 미국신체190cm가족남동생, 여동생활동 시기1997년 ~ 현재링크홈페이지 출연 목록 위키1. 개요2. 출연작2.1. 애니메이션2.2. 게임2.3. 외화3. 기타4. 관련 문서미국의 성우. 데뷔작은 <은하철도의 밤>의 캄파넬라 역이다. 제일 유명한 배역은 <헬싱>의 아카드로 싱크로율이 높다는 평가를 받았다.[1]백인이지만 아래 출연작에 보이는 브루스 어빈이나 루드 같은 흑인 역도 잘 소화한다.연기나 작품과는 별개로 상당한 미남에 동안[2]인데, 동안의 조건 중 하나인 큰 눈과 더불어 백인치고는 드물게 동글동글한 얼굴형에 수염도 없어서 더 동안으로 보인다.보이스 액팅 마스터리라는 성우 양성 학원을 설립했으며[3], 모린 프라이스와 톰 바우어를 강사로 두었다.[4]아버지가 유대인이다.#BLOOD+ - 하지Fate 시리즈 - 코토미네 키레이(Fate/Zero 이후)X(TV) - 모노우 후마교향시편 에우레카 세븐 - 홀랜드귀멸의 칼날 - 히메지마 교메이나루토 - 우치하 이타치, 4대 카제카게듀라라라!! - 헤이와지마 시즈오디지몬 세이버즈 - 토마 H. 놀슈타인디지몬 프론티어 - 선우윤레이브 - 슈다바이오하자드 디제네레이션 - 프레데릭 다우닝바람의 검심 - 아마쿠사 쇼고반요 야샤히메 - 키린 오사무 / 키린마루슈팅 바쿠간 - 거스 그라브스즈미야 하루히의 우울 - 쿈스크라이드 - 스트레이트 쿠거슬레이어즈 - 제르가디스 그레이워즈소녀혁명 우테나 - 키류 토우가영 저스티스 - 레드 애로우, 가디언울프스 레인 - 츠메은하철도의 밤 - 캄파넬라천사의 꼬리 - 현무의 신쵸비츠 - 모토스와 히데키코드 기아스 반역의 를르슈 - 제레미아 고트발트텐카이나이트 - 빌리우스, 슬라이거, 내비플리즈 트윈즈 - 시마자키 코우세이헬싱 - 아카드무책임함장 테일러 - 저스티 우에키 테일러갓 오브 워 3 - 헬리오스디아블로 3 - 남성 마법사마그나카르타 2 - 알렉스 라이몬 루도메탈기어 라이징 리벤전스 - 선다우너소울 칼리버 3 - 지크프리트 슈타우펜아우터 월드 - 찰스 록웰아캄버스 시리즈 - 파이어플라이악마성 시리즈Castlevania - 마티어스 크론크비스트Castlevania: Curse of Darkness - 헥터오버워치 - 윈스턴워크래프트 시리즈 - 탈렌 송위버, 구원자 마라아드, 알로디진삼국무쌍 7 맹장전 - 법정저지 아이즈: 사신의 유언 - 카이토 마사하루철권 시리즈 - 브루스 어빈(5편부터)파이널 판타지 7 어드벤트 칠드런 - 루드호라이즌 제로 던 - 헬리스데이즈 곤 - 마크 코프랜드레고 DC 슈퍼빌런 - 아스널, 파이어플라이, 리들러 부하올드보이 - 이우진(유지태 분)영어와 스페인어에 능숙하다.일본판 쿈의 성우인 스기타 토모카즈와 만나기도 했다.성우/북미

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# %%
# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 데이터 프레임을 출력합니다.
df.head(5)
# Out:
#                 title                                        category  \
# 0           크리스핀 프리먼   미국의 남성 성우/ㅋ1972년 출생일리노이 주 출신 인물1997년 데뷔유대계 미국인
# 1                김나라                                           동명이인/ㄱ
# 2          허수(프로게이머)          DWG KIA프로게이머/리그 오브 레전드2000년 출생시흥시 출신 인물
# 3               도지코인                                     암호화폐2013년 출시
# 4  도날드 덕 가족의 모험/등장인물                                      덕테일즈디즈니 캐릭터
#
#                                         content_text
# 0  크리스핀 프리먼Crispin Freeman이름크리스핀 맥두걸 프리먼(Crispin ...
# 1  1. DWG KIA 소속의 발로란트 프로게이머2. 개를 낳았다의 등장인물    자세...
# 2  DWG KIA2021 시즌 로스터DWG KIA2021 시즌 로스터 [ 펼치기 · 접...
# 3     로그인 후 편집 가능한 문서입니다.주요 암호 화폐 [ 펼치기 · 접기 ]비트코...
# 4     상위 문서: 도날드 덕 가족의 모험이 문서에 스포일러가 포함되어 있습니다.이 ...

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result #한글만 갖는 텍스트 담음

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
# 크리스핀 프리먼 이름크리스핀 맥두걸 프리먼  출생년 월 일 세미국 일리노이 주 시카고국적 미국신체가족남동생 여동생활동 시기년  현재링크홈페이지 출연 목록 위키 개요 출연작 애니메이션 게임 외화 기타 관련 문서미국의 성우 데뷔작은 은하철도의 밤의 캄파넬라 역이다 제일 유명한 배역은 헬싱의 아카드로 싱크로율이 높다는 평가를 받았다백인이지만 아래 출연작에 보이는 브루스 어빈이나 루드 같은 흑인 역도 잘 소화한다연기나 작품과는 별개로 상당한 미남에 동안인데 동안의 조건 중 하나인 큰 눈과 더불어 백인치고는 드물게 동글동글한 얼굴형에 수염도 없어서 더 동안으로 보인다보이스 액팅 마스터리라는 성우 양성 학원을 설립했으며 모린 프라이스와 톰 바우어를 강사로 두었다아버지가 유대인이다  하지 시리즈  코토미네 키레이 이후  모노우 후마교향시편 에우레카 세븐  홀랜드귀멸의 칼날  히메지마 교메이나루토  우치하 이타치 대 카제카게듀라라라  헤이와지마 시즈오디지몬 세이버즈  토마  놀슈타인디지몬 프론티어  선우윤레이브  슈다바이오하자드 디제네레이션  프레데릭 다우닝바람의 검심  아마쿠사 쇼고반요 야샤히메  키린 오사무  키린마루슈팅 바쿠간  거스 그라브스즈미야 하루히의 우울  쿈스크라이드  스트레이트 쿠거슬레이어즈  제르가디스 그레이워즈소녀혁명 우테나  키류 토우가영 저스티스  레드 애로우 가디언울프스 레인  츠메은하철도의 밤  캄파넬라천사의 꼬리  현무의 신쵸비츠  모토스와 히데키코드 기아스 반역의 를르슈  제레미아 고트발트텐카이나이트  빌리우스 슬라이거 내비플리즈 트윈즈  시마자키 코우세이헬싱  아카드무책임함장 테일러  저스티 우에키 테일러갓 오브 워   헬리오스디아블로   남성 마법사마그나카르타   알렉스 라이몬 루도메탈기어 라이징 리벤전스  선다우너소울 칼리버   지크프리트 슈타우펜아우터 월드  찰스 록웰아캄버스 시리즈  파이어플라이악마성 시리즈  마티어스 크론크비스트     헥터오버워치  윈스턴워크래프트 시리즈  탈렌 송위버 구원자 마라아드 알로디진삼국무쌍  맹장전  법정저지 아이즈 사신의 유언  카이토 마사하루철권 시리즈  브루스 어빈편부터파이널 판타지  어드벤트 칠드런  루드호라이즌 제로 던  헬리스데이즈 곤  마크 코프랜드레고  슈퍼빌런  아스널 파이어플라이 리들러 부하올드보이  이우진유지태 분영어와 스페인어에 능숙하다일본판 쿈의 성우인 스기타 토모카즈와 만나기도 했다성우북미

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#                title                               category  \
# 0          크리스핀 프리먼   미국의 남성 성우ㅋ년 출생일리노이 주 출신 인물년 데뷔유대계 미국인
# 1               김나라                                   동명이인ㄱ
# 2           허수프로게이머             프로게이머리그 오브 레전드년 출생시흥시 출신 인물
# 3              도지코인                                암호화폐년 출시
# 4  도날드 덕 가족의 모험등장인물                             덕테일즈디즈니 캐릭터
#
#                                         content_text
# 0  크리스핀 프리먼 이름크리스핀 맥두걸 프리먼  출생년 월 일 세미국 일리노이 주 시카...
# 1     소속의 발로란트 프로게이머 개를 낳았다의 등장인물   자세한 내용은 김나라프로...
# 2    시즌 로스터  시즌 로스터  펼치기  접기 감독김정균 코치이정현 김민권 로스터 ...
# 3    로그인 후 편집 가능한 문서입니다주요 암호 화폐  펼치기  접기 비트코인이더리움...
# 4    상위 문서 도날드 덕 가족의 모험이 문서에 스포일러가 포함되어 있습니다이 문서가...

# %%
# 각 피처마다 말뭉치를 생성합니다.
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 크리스핀 프리먼 김나라 허수프로게이머 도지코인 도날드 덕 가족의 모험등장인물 바이오하자드 빌리지 김태술 페미니즘 고려대학교주변 상권 구해줘 철십자 기사단 아틀레티코 마드리드 시즌 카프록시아 황진성 머리카락빨간색캐릭터 등장인물 미인 그려놓고 평범하다고 우기기   눈신체파란색 정미의병 류진 치아교정  삼각형 아론 람스데일 미야타 코우키 안전신문고 세계 최강의 노력가 재능이 노력이었으므로 효율적으로 규격외의 노력을 해보겠습니다 용과 같이 유신 후지 키세키우마무스메   조 바이든년 사우스 파크 국회의원 다이루크 소녀전선 벨벳케이크맛 쿠키 쿠키런 킹덤쿠키 콜 오브 듀티 블랙 옵스 콜드 워장비류주무기 타이탄다크 스토리 시리즈 크리스토퍼 파이크 어느 날 우리 집 현관으로 멸망이 들어왔다 배재대학교   성우계 단신 부활차 김건부선수 경력 호위함대 오버레이 유니버스 복합부위 통증 증후군 파일 건담 나드레  파이널 판타지  코로나바이러스감염증경과년 월 레이븐엘소드레이지 하츠 더미김나라개를 낳았다 파일 건담 버체  정난의 변 헤일리   매더스 다크나이트던전 앤 파이터스킬 적기사 분류묵향 다크레이디등장인물 나치즘 아틀레티코 마드리드 시즌리그 기쁜 우리 토요일 옴므    손 마사요시 아스날  시즌리그 메가미 디바이스 제인격    파이널 판타지  에버 크라이시스 산타클로스서브컬쳐 개성나의 히어로 아카데미아 정두만 유엔군사령부 청기사다크 스토리 시리즈

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

# %%
count
# Out:
# Counter({'크리': 30,
#          '스핀': 15,
#          '프리': 54,
#          '이름': 197,
#          '맥': 43,
#          '걸': 247,
#          '출생': 16,
#          '년': 1113,
#          '월': 898,
#          '일': 803,
#          '미국': 193,
#          '일리노이': 1,
#          '주': 56,
#          '시카고': 1,
#          '국적': 23,
#          '신체': 52,
#          '가족': 157,
#          '남동생': 3,
#          '여동생': 11,
#          '활동': 93,
#          '시기': 53,
#          '현재': 168,
#          '링크': 46,
#          '홈페이지': 42,
#          '출연': 92,
#          '목록': 50,
#          '위키': 33,
#          '개요': 59,
#          '작': 147,
#          '애니메이션': 74,
#          '게임': 439,
#          '외화': 2,
#          '기타': 88,
#          '관련': 197,
#          '성우': 332,
#          '데뷔': 40,
#          '은하': 10,
#          '철도': 3,
#          '밤': 56,
#          '캄파넬라': 2,
#          '역': 114,
#          '제일': 32,
#          '배역': 18,
#          '헬싱': 2,
#          '아카드': 2,
#          '싱크로': 5,
#          '율': 101,
#          '평가': 208,
#          '백인': 18,
#          '아래': 63,
#          '브루스': 10,
#          '어빈': 2,
#          '루드': 7,
#          '흑인': 21,
#          '역도': 3,
#          '소화': 18,
#          '한다연': 1,
#          '기': 307,
#          '작품': 144,
#          '별개': 36,
#          '미남': 174,
#          '동안': 145,
#          '조건': 47,
#          '중': 806,
#          '하나': 310,
#          '눈': 169,
#          '동글동글': 4,
#          '얼굴': 166,
#          '수염': 24,
#          '더': 656,
#          '보이스': 30,
#          '액팅': 1,
#          '마스터': 241,
#          '리라': 6,
#          '양성': 14,
#          '학원': 30,
#          '설립': 21,
#          '린': 127,
#          '프라': 12,
#          '이스': 21,
#          '톰': 13,
#          '바우어': 2,
#          '강사': 2,
#          '아버지': 105,
#          '유대인': 29,
#          '시리즈': 417,
#          '코': 410,
#          '토미': 3,
#          '키': 293,
#          '레이': 234,
#          '이후': 601,
#          '모노': 5,
#          '후마': 4,
#          '교향시': 1,
#          '편': 276,
#          '레카': 1,
#          '세븐': 13,
#          '홀랜드': 2,
#          '멸': 4,
#          '칼날': 16,
#          '히메지': 1,
#          '마': 137,
#          '교': 29,
#          '메이': 43,
#          '나루토': 14,
#          '우치': 8,
#          '타치': 3,
#          '카제': 6,
#          '카': 283,
#          '듀라라라': 2,
#          '헤': 3,
#          '디지몬': 21,
#          '세이': 71,
#          '버즈': 2,
#          '토마': 216,
#          '놀': 6,
#          '슈타인': 5,
#          '프론티어': 3,
#          '선': 143,
#          '우윤': 3,
#          '레이브': 15,
#          '슈': 32,
#          '바이오하자드': 114,
#          '디': 98,
#          '션': 94,
#          '프레데릭': 2,
#          '다우': 3,
#          '닝': 3,
#          '바람': 100,
#          '검심': 2,
#          '아마': 34,
#          '쿠사': 1,
#          '쇼': 231,
#          '반': 60,
#          '야샤히메': 1,
#          '키린': 2,
#          '사무': 4,
#          '마루': 18,
#          '슈팅': 77,
#          '바쿠간': 3,
#          '거스': 2,
#          '그라브스즈미': 1,
#          '하루히': 5,
#          '우울': 1,
#          '쿈스크': 1,
#          '라이드': 11,
#          '스트레이트': 2,
#          '쿠거': 1,
#          '슬레이어즈': 2,
#          '제르': 2,
#          '가디스': 1,
#          '그레이': 14,
#          '워': 83,
#          '소녀': 62,
#          '혁명': 20,
#          '우테나': 1,
#          '키류': 8,
#          '토우': 12,
#          '영': 38,
#          '저스티스': 4,
#          '레드': 120,
#          '애로우': 5,
#          '가디언': 31,
#          '울프': 12,
#          '스': 293,
#          '레인': 13,
#          '츠메': 1,
#          '천사': 39,
#          '꼬리': 14,
#          '현무': 1,
#          '쵸비츠': 1,
#          '토스': 8,
#          '히데': 13,
#          '코드': 93,
#          '기아스': 3,
#          '반역': 9,
#          '를르슈': 2,
#          '제레미아': 2,
#          '고트발트': 1,
#          '텐카이': 1,
#          '나이트': 95,
#          '우스': 49,
#          '슬': 12,
#          '라이거': 1,
#          '내비': 3,
#          '리즈': 34,
#          '트윈즈': 1,
#          '시마': 21,
#          '자키': 14,
#          '우세': 7,
#          '무책임': 1,
#          '함장': 2,
#          '테일러': 9,
#          '스티': 12,
#          '갓': 7,
#          '오브': 163,
#          '헬리오스': 3,
#          '디아블로': 5,
#          '남성': 191,
#          '마법사': 71,
#          '마그나카르타': 1,
#          '알렉스': 8,
#          '라이': 60,
#          '몬': 13,
#          '루': 72,
#          '메탈기어': 5,
#          '징': 53,
#          '리벤전스': 1,
#          '다우너': 1,
#          '소울': 21,
#          '칼': 66,
#          '리버': 29,
#          '지크프리트': 4,
#          '타우': 1,
#          '펜': 17,
#          '아우': 4,
#          '터': 264,
#          '월드': 55,
#          '찰스': 6,
#          '록웰': 1,
#          '아캄': 1,
#          '버스': 93,
#          '파이어플라이': 5,
#          '악마': 39,
#          '티어스': 6,
#          '크론': 2,
#          '비스트': 7,
#          '헥터': 2,
#          '오버': 38,
#          '워치': 12,
#          '윈스턴': 1,
#          '워크래프트': 10,
#          '탈렌': 1,
#          '송위버': 1,
#          '구원': 22,
#          '드': 146,
#          '알': 188,
#          '로디': 225,
#          '진삼국무쌍': 1,
#          '맹장': 1,
#          '전': 506,
#          '법정': 3,
#          '저지': 25,
#          '아이즈': 27,
#          '사신': 12,
#          '유언': 7,
#          '카이토': 4,
#          '마사': 38,
#          '하루': 64,
#          '철권': 13,
#          '파이널': 94,
#          '판타지': 108,
#          '어드': 6,
#          '벤트': 12,
#          '칠': 16,
#          '호': 207,
#          '즌': 4,
#          '제로': 33,
#          '던': 43,
#          '헬': 49,
#          '리스': 118,
#          '데이즈': 6,
#          '곤': 25,
#          '마크': 47,
#          '코프': 2,
#          '랜드': 41,
#          '레고': 8,
#          '슈퍼빌런': 1,
#          '아스널': 4,
#          '리': 182,
#          '부하': 22,
#          '올드보이': 1,
#          '이우진': 4,
#          '유지태': 1,
#          '분': 244,
#          '영어': 33,
#          '스페인어': 4,
#          '판': 997,
#          '쿈': 2,
#          '토': 325,
#          '모카': 6,
#          '와': 1,
#          '북미': 23,
#          '소속': 81,
#          '발': 379,
#          '로란': 1,
#          '트': 192,
#          '프로게이머': 7,
#          '개': 448,
#          '등장인물': 70,
#          '내용': 342,
#          '김나라': 2,
#          '를': 477,
#          '번': 1690,
#          '문단': 1122,
#          '의': 1021,
#          '부분': 521,
#          '참고': 186,
#          '시즌': 945,
#          '로스': 31,
#          '접기': 269,
#          '감독': 87,
#          '김정균': 3,
#          '코치': 12,
#          '이정현': 9,
#          '김민': 2,
#          '김동하': 8,
#          '김건': 17,
#          '부': 203,
#          '김근성': 2,
#          '허수': 51,
#          '장용': 5,
#          '준': 82,
#          '조건희': 2,
#          '참가': 17,
#          '팀': 449,
#          '틀': 38,
#          '리그': 207,
#          '레전드': 45,
#          '챔피언십': 11,
#          '우승자': 3,
#          '우승팀': 6,
#          '포지션': 60,
#          '별': 131,
#          '선수': 223,
#          '및': 254,
#          '챔피언스': 36,
#          '코리아': 22,
#          '우승': 70,
#          '구분': 23,
#          '대회': 31,
#          '스프링': 61,
#          '서머': 54,
#          '윈터': 10,
#          '역대': 57,
#          '정규': 50,
#          '구': 133,
#          '롤챔스': 3,
#          '이호성': 3,
#          '김찬호': 6,
#          '송경호': 9,
#          '이민호': 9,
#          '서행': 3,
#          '곽': 17,
#          '보성': 17,
#          '정지훈': 7,
#          '포인트': 171,
#          '시상': 12,
#          '투표제': 3,
#          '위': 1055,
#          '상': 57,
#          '다리': 92,
#          '류민석': 4,
#          '홍창현': 6,
#          '점수': 47,
#          '가장': 318,
#          '펜타킬': 10,
#          '달성': 51,
#          '이우석': 3,
#          '최윤섭': 3,
#          '김강': 5,
#          '환': 20,
#          '구승': 6,
#          '빈': 33,
#          '강찬용': 3,
#          '백승민': 3,
#          '김종인': 3,
#          '김진현': 3,
#          '식': 133,
#          '이상혁': 3,
#          '박': 19,
#          '단원': 8,
#          '노동현': 3,
#          '김상': 3,
#          '문': 61,
#          '나우': 14,
#          '이승주': 3,
#          '권상윤': 3,
#          '강명구': 3,
#          '종훈': 3,
#          '전익수': 3,
#          '김태훈': 3,
#          '박진성': 3,
#          '박재혁': 9,
#          '박도현': 3,
#          '김': 42,
#          '태양': 9,
#          '진성준': 3,
#          '김하람': 3,
#          '호호': 3,
#          '김준영': 3,
#          '이민형': 3,
#          '국내': 52,
#          '제외': 158,
#          '마스터즈': 6,
#          '예선': 6,
#          '챌린저스': 3,
#          '승': 94,
#          '강전': 7,
#          '케스파': 9,
#          '컵': 24,
#          '등': 796,
#          '회': 198,
#          '세': 183,
#          '경기도': 28,
#          '시흥시': 1,
#          '상동': 1,
#          '대한민국': 86,
#          '학력': 10,
#          '연성': 1,
#          '중학교': 17,
#          '졸업': 33,
#          '시흥': 1,
#          '고등학교': 26,
#          '중퇴': 4,
#          '뢰이가르달스회들': 1,
#          '미드': 58,
#          '계약': 81,
#          '종료': 75,
#          '병역': 5,
#          '보충역': 1,
#          '상세': 8,
#          '플레이': 221,
#          '스타일': 50,
#          '경력': 21,
#          '주요': 38,
#          '별명': 32,
#          '여담': 82,
#          '초월': 169,
#          '번역': 75,
#          '메이커': 89,
#          '말': 516,
#          '라이너': 34,
#          '승격': 8,
#          '곧바로': 7,
#          '롤드컵': 25,
#          '진출': 37,
#          '출신': 76,
#          '최': 50,
#          '연속': 52,
#          '오프': 11,
#          '기록': 161,
#          '세운': 9,
#          '초': 349,
#          '솔랭': 13,
#          '패': 232,
#          '시': 687,
#          '기준': 190,
#          '점': 389,
#          '타잔': 4,
#          '랭크': 8,
#          '최고': 102,
#          '본인': 170,
#          '계속': 152,
#          '갱신': 10,
#          '또한': 327,
#          '기용': 32,
#          '거의': 178,
#          '모든': 272,
#          '챔피언': 20,
#          '사용': 604,
#          '중복': 23,
#          '각기': 2,
#          '한판': 1,
#          '티어': 231,
#          '화제': 17,
#          '아칼리': 4,
#          '코르키': 2,
#          '투': 27,
#          '소리': 67,
#          '욱해': 2,
#          '도전': 27,
#          '국제': 32,
#          '때': 912,
#          '계정': 26,
#          '항상': 40,
#          '상위': 59,
#          '관해': 2,
#          '자가': 26,
#          '내': 269,
#          '신뢰': 14,
#          '도': 163,
#          '너구리': 27,
#          '고스트': 9,
#          '공식': 188,
#          '인터뷰': 205,
#          '영상': 110,
#          '실력': 43,
#          '대해': 200,
#          '찬사': 2,
#          '적': 495,
#          '우리': 102,
#          '상체': 16,
#          '괴물': 23,
#          '살': 197,
#          '요나': 1,
#          '상대': 269,
#          '누구': 35,
#          '질': 32,
#          '것': 2019,
#          '난': 90,
#          '네': 50,
#          '성장': 28,
#          '대치': 6,
#          '언급': 202,
#          '그': 1099,
#          '사랑': 64,
#          '일기': 10,
#          '수': 1611,
#          '서포터': 6,
#          '베릴': 12,
#          '역시': 210,
#          '경기': 799,
#          '망': 16,
#          '종종': 30,
#          '승리': 186,
#          '원인': 36,
#          '다라': 10,
#          '감': 76,
#          '뉴클리어': 24,
#          '개인': 74,
#          '방송': 110,
#          '육각형': 4,
#          '꽉': 8,
#          '찬': 14,
#          '급': 59,
#          '라며': 29,
#          '칭찬': 16,
#          '외': 149,
#          '페이커': 9,
#          '폰': 51,
#          '루키': 7,
#          '도인': 2,
#          '비': 441,
#          '인정': 62,
#          '임팩트': 11,
#          '강': 102,
#          '체제': 19,
#          '명가': 1,
#          '주자': 5,
#          '요소': 70,
#          '극찬': 6,
#          '롤': 24,
#          '대한': 404,
#          '열정': 6,
#          '보고': 122,
#          '결승': 17,
#          '준비': 53,
#          '당일': 6,
#          '인터넷': 25,
#          '쿠로': 23,
#          '정점': 3,
#          '커리어': 6,
#          '도달': 15,
#          '자세': 17,
#          '보이': 108,
#          '팬': 183,
#          '입장': 89,
#          '응원': 18,
#          '기복': 9,
#          '저': 128,
#          '자기': 111,
#          '이상': 260,
#          '정의': 49,
#          '담': 42,
#          '톱니바퀴': 2,
#          '명': 983,
#          '압도': 63,
#          '피지': 16,
#          '컬': 54,
#          '교전': 39,
#          '위치': 146,
#          '선정': 69,
#          '타': 205,
#          '딜': 51,
#          '뿐': 96,
#          '스스로': 49,
#          '각': 84,
#          '잡고': 22,
#          '설계': 23,
#          '관': 115,
#          '타의': 23,
#          '추종': 5,
#          '불허': 4,
#          '공격': 753,
#          '특성': 149,
#          '통한': 22,
#          '혈': 5,
#          '균형': 11,
#          '브루': 64,
#          '로': 423,
#          '초반': 113,
#          '니시': 8,
#          '여': 18,
#          '모습': 431,
#          '메이지': 14,
#          '암살자': 4,
#          '원딜': 8,
#          '게': 198,
#          '물어': 4,
#          '장면': 122,
#          '매': 58,
#          '볼': 212,
#          '정도': 579,
#          '유틸': 5,
#          '팀원': 8,
#          '보조': 42,
#          '라인': 273,
#          '로밍': 7,
#          '캐리': 23,
#          '대형': 18,
#          '오브젝트': 3,
#          '스틸': 20,
#          '자주': 110,
#          '면': 64,
#          '만능': 12,
#          '표본': 1,
#          '후반': 153,
#          '딜링': 23,
#          '능력': 201,
#          '속': 165,
#          '일반': 165,
#          '대부분': 147,
#          '중후': 9,
#          '기량': 8,
#          '좌우': 18,
#          '고': 48,
#          '의존': 8,
#          '안정': 40,
#          '때문': 763,
#          '짤리': 1,
#          '경우': 700,
#          '딜러': 20,
#          '로서': 53,
#          '풀딜': 1,
#          '다른': 480,
#          '몫': 18,
#          '전부': 101,
#          '딜로': 7,
#          '하이라이트': 51,
#          '챔프': 9,
#          '폭': 35,
#          '편이': 175,
#          '면서': 37,
#          '특정': 38,
#          '픽': 30,
#          '파괴': 65,
#          '특징': 60,
#          '그냥': 137,
#          '처': 75,
#          '일명': 17,
#          '칼리': 8,
#          '픽할': 2,
#          '세계': 136,
#          '무대': 39,
#          '처음': 182,
#          '데': 240,
#          '기여': 16,
#          '이렐리아': 1,
#          '아트록스': 2,
#          '조이': 16,
#          '정통': 12,
#          '숙련': 13,
#          '그다지': 23,
#          '상태': 300,
#          '스킬': 674,
#          '적중': 29,
#          '률': 55,
#          '시야': 28,
#          '이용': 118,
#          '포지셔닝': 3,
#          '탱크': 4,
#          '라운드': 128,
#          '시경': 2,
#          '중이': 45,
#          '듯': 279,
#          '보기': 83,
#          '신드라': 7,
#          '장인': 6,
#          '답': 49,
#          '전체': 172,
#          '주류': 15,
#          '와중': 23,
#          '폼': 51,
#          '카사딘': 7,
#          '플레이도': 6,
#          '픽했': 4,
#          '레벨': 543,
#          '렙': 5,
#          '능동': 1,
#          '해설': 6,
#          '진': 157,
#          '쪽': 168,
#          '도모': 3,
#          '정석': 8,
#          '실제': 207,
#          '가선': 2,
#          '채': 72,
#          '킬': 33,
#          '쇼사딘': 1,
#          '위력': 27,
#          '후픽': 1,
#          '카드': 84,
#          '만하': 15,
#          '등장': 399,
#          '늘': 20,
#          '린지': 5,
#          '연일': 3,
#          '사일러': 5,
#          '제이스': 2,
#          '트페': 9,
#          '갈리오': 1,
#          '이제': 68,
#          '저격': 73,
#          '유': 76,
#          '불리': 20,
#          '슈퍼': 99,
#          '적수': 1,
#          '찾기': 8,
#          '진행': 122,
#          '후의': 6,
#          '트위스티드': 1,
#          '페이트': 5,
#          '조작': 23,
#          '난이도': 69,
#          '운영': 71,
#          '이기': 108,
#          '무력': 17,
#          '치중': 1,
#          '신예': 1,
#          '완벽': 4,
#          '수준': 173,
#          '시작': 280,
#          '최근': 66,
#          '전적': 17,
#          '승률': 9,
#          '스노우볼': 1,
#          '속도': 356,
#          '어선': 1,
#          '안': 322,
#          '스킨': 111,
#          '꼽': 3,
#          '덤전': 1,
#          '샌드박스': 1,
#          '야마토': 4,
#          '캐논': 5,
#          '리스크': 11,
#          '땐': 18,
#          '판단': 33,
#          '짊어지': 2,
#          '시도': 44,
#          '압박': 42,
#          '솔킬': 1,
#          '전성기': 14,
#          '장점': 51,
#          '기본': 210,
#          '매우': 332,
#          '바탕': 21,
#          '최대한': 22,
#          '수행': 26,
#          '무리': 13,
#          '이득': 9,
#          '굴리': 2,
#          '중간': 61,
#          '평소': 25,
#          '공격성': 1,
#          '조절': 27,
#          '함': 74,
#          '시너지': 20,
#          '대화': 48,
#          '변수': 8,
#          '상황': 311,
#          '창': 138,
#          '위해': 337,
#          '주도': 13,
#          '강점': 11,
#          '부각': 23,
#          '인기': 88,
#          '차력': 2,
#          '확보': 14,
#          '합류': 24,
#          '좀': 115,
#          '주력': 42,
#          '거나': 114,
#          '통해': 148,
#          '존재': 239,
#          '안티': 15,
#          '역할': 120,
#          '주로': 86,
#          '메타': 31,
#          '영향': 106,
#          '탈락': 34,
#          '캡스': 4,
#          '발언': 30,
#          '만큼': 114,
#          '스펠': 16,
#          '체크': 15,
#          '동시': 92,
#          '장악': 15,
#          '위주': 28,
#          '움직임': 23,
#          '과거': 80,
#          '전과': 12,
#          '필요': 65,
#          '과감': 5,
#          '메이킹': 11,
#          '특유': 36,
#          '템포': 5,
#          '중심': 57,
#          '정글': 101,
#          '가치': 33,
#          '스무살': 2,
#          '리프트': 4,
#          '라이벌': 20,
#          '우리은행': 11,
#          '그룹': 17,
#          '스테이지': 35,
#          '어워드': 6,
#          '올해': 4,
#          '스포츠': 21,
#          '통산': 4,
#          '총': 257,
#          '데스': 17,
#          '어시': 5,
#          '관여': 11,
#          '폐지': 11,
#          '미정': 28,
#          '수상': 24,
#          '김기인': 1,
#          '홍창': 1,
#          '명예': 10,
#          '전당': 2,
#          '히어로즈': 9,
#          '쇼붕': 2,
#          '플레임': 28,
#          '막눈': 1,
#          '김민아': 1,
#          '아나운서': 1,
#          '하이파이브': 1,
#          '비교': 103,
#          '반응': 100,
#          '차이': 100,
#          '로부터': 39,
#          '동정': 5,
#          '주변': 103,
#          '사람': 347,
#          '외모': 328,
#          '농담': 16,
#          '진담': 1,
#          '대인': 10,
#          '안경': 27,
#          '문제': 298,
#          '킹': 47,
#          '카밀': 2,
#          '또': 116,
#          '너': 80,
#          '성': 144,
#          '레코드': 7,
#          '드립': 17,
#          '치면': 14,
#          '호응': 5,
#          '본명': 14,
#          '덩달아': 3,
#          '맨': 47,
#          '듀오': 11,
#          '환상': 26,
#          '둘': 84,
#          '꼭': 25,
#          '인어': 5,
#          '조개': 1,
#          '소년': 49,
#          '굴': 5,
#          '닉네임': 7,
#          '뒷받침': 3,
#          '애국': 2,
#          '랭킹': 51,
#          '북극곰': 2,
#          '자신': 440,
#          '중국인': 5,
#          '연습생': 10,
#          '탈환': 2,
#          '닉': 217,
#          '다시': 265,
#          '다음': 135,
#          '당시': 212,
#          '변경': 84,
#          '멕': 2,
#          '제발': 5,
#          '한국인': 17,
#          '이면': 21,
#          '이': 1230,
#          '실수': 26,
#          '포함': 146,
#          '치기': 15,
#          '제목': 18,
#          '섬네일': 1,
#          '수면': 4,
#          '자요': 1,
#          '쌩쇼': 1,
#          '활약': 110,
#          '반대': 104,
#          '킹쇼': 1,
#          '해외': 38,
#          '한정': 86,
#          '쇼메': 1,
#          '보드': 14,
#          '자의': 23,
#          '서구': 10,
#          '불사': 3,
#          '마왕': 12,
#          '계승': 12,
#          '의미': 118,
#          '뜻': 58,
#          '대충': 12,
#          '대마': 3,
#          '공': 38,
#          '상하이': 3,
#          '도서관': 11,
#          '세트': 65,
#          '라이브러리': 1,
#          '진짜': 43,
#          '원툴': 3,
#          '주장': 126,
#          '이자': 60,
#          '온갖': 22,
#          '오타쿠': 1,
#          '유래': 13,
#          '후': 493,
#          '염탐': 2,
#          '앞담': 1,
#          '튜토리얼': 10,
#          '보스': 74,
#          '못': 293,
#          '풀기': 1,
#          '아예': 103,
#          '확인': 79,
#          '사살': 23,
#          '트위치': 13,
#          '켜': 3,
#          '경악': 11,
#          '왜': 53,
#          '이유': 145,
#          '납득': 17,
#          '이전': 872,
#          '유튜버': 8,
#          '도파': 2,
#          '지목': 4,
#          '제': 125,
#          '뉘앙스': 2,
#          '커뮤니티': 33,
#          '주목': 17,
#          '다만': 224,
#          '그때': 23,
#          '최상급': 2,
#          '파의': 4,
#          '팬덤': 19,
#          '안목': 1,
#          '무시': 71,
#          '인지도': 9,
#          '악플': 3,
#          '성적': 47,
#          '해당': 215,
#          '패러디': 16,
#          '표현': 65,
#          '조롱': 8,
#          '성의': 29,
#          '더욱': 88,
#          '예측': 22,
#          '예전': 15,
#          '주춤': 2,
#          '재': 101,
#          '수도': 123,
#          '와우': 4,
#          '재혁': 1,
#          '오늘': 23,
#          '뱅': 8,
#          '두고두고': 1,
#          '퍼포먼스': 6,
#          '제압': 43,
#          '차지': 72,
#          '밈': 15,
#          '이슈': 14,
#          '가운데': 42,
#          '지배': 28,
#          '포스': 33,
#          '이야기': 114,
#          '세밀': 4,
#          '딜교환': 2,
#          '꼽았다': 1,
#          '라면': 82,
#          '무조건': 41,
#          '우위': 25,
#          '생각': 247,
#          '부모님': 12,
#          '직관': 2,
#          '오시': 3,
#          '번은': 3,
#          '풀': 52,
#          '허수아비': 3,
#          '자식': 12,
#          ...})

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'문단': 1122, '문서': 952, '시즌': 945, '이전': 872, '역사': 831, '경기': 799, '때문': 763, '공격': 753, '경우': 700, '스킬': 674, '사용': 604, '이후': 601, '정도': 579, '레벨': 543, '캐릭터': 543, '쿠키': 526, '부분': 521, '시간': 519, '다른': 480, '자신': 440, '게임': 439, '모습': 431, '생존자': 422, '합의': 419, '사항': 418, '토론': 418, '시리즈': 417, '대한': 404, '등장': 399, '페미니즘': 396, '감시자': 380, '증가': 373, '학교': 370, '비치': 364, '속도': 356, '설정': 354, '사람': 347, '내용': 342, '위해': 337, '손잡이': 334, '성우': 332, '매우': 332, '외모': 328, '또한': 327, '여성': 326, '마법': 322, '가장': 318, '아스날': 316, '상황': 311, '하나': 310, '사실': 305, '상태': 300, '효과': 299, '문제': 298, '탄창': 298, '시작': 280, '루이스': 276, '스톡': 276, '라인': 273, '모든': 272, '접기': 269, '상대': 269, '스크루': 269, '다크': 268, '추가': 266, '한국': 266, '코레아': 266, '다시': 265, '프레': 264, '모두': 261, '이상': 260, '가지': 256, '수아레스': 253, '전투': 250, '펠릭스': 250, '앙헬': 249, '생각': 247, '주의': 246, '요렌테': 246, '마르코스': 245, '트리': 243, '마스터': 241, '존재': 239, '아이템': 239, '해독': 238, '레이': 234, '티어': 231, '주앙': 229, '마리오': 228, '개성': 227, '루카스': 226, '레이라': 226, '로디': 225, '르마': 225, '다만': 224, '선수': 223, '몬테': 222, '플레이': 221, '마드리드': 221, '대학교': 218, '타이탄': 218, '에르': 218, '감소': 218, '토마': 216, '무기': 216, '헤낭': 216, '해당': 215, '최대': 215, '리페': 214, '스피드': 213, '이루': 213, '당시': 212, '데미지': 211, '티코': 211, '톨로': 211, '역시': 210, '기본': 210, '평가': 208, '리그': 207, '실제': 207, '카라스': 207, '블락': 206, '사울': 206, '인터뷰': 205, '폭발': 205, '언급': 202, '대원': 202, '능력': 201, '코케': 201, '게스': 201, '대해': 200, '전용': 199, '대학': 198, '이름': 197, '관련': 197, '비아': 195, '미국': 193, '남성': 191, '마지막': 191, '기준': 190, '명단': 190, '공식': 188, '토르': 188, '이보': 187, '참고': 186, '승리': 186, '건축학': 186, '키어런': 185, '대전': 184, '자체': 183, '스테판': 183, '처음': 182, '인물': 179, '스타': 179, '대미지': 179, '거의': 178, '기사': 178, '교정': 176, '편이': 175, '미남': 174, '소모': 174, '수준': 173, '전체': 172, '포인트': 171, '시전': 171, '피어': 171, '본인': 170, '초월': 169, '바로': 169, '현재': 168, '머리': 168, '타격': 168, '얼굴': 166, '일본': 166, '일반': 165, '오브': 163, '나소드': 162, '기록': 161, '여기': 161, '제외': 158, '검사': 158, '유저': 158, '가족': 157, '버전': 157, '아이': 156, '결과': 154, '이번': 154, '후반': 153, '달리': 153, '패스': 153, '계속': 152, '레이저': 152, '건축': 151, '미인': 150, '특성': 149, '강화': 149, '전반': 149, '묘사': 149, '가드': 149, '통해': 148, '대신': 148, '모드': 148, '산체스': 148, '대부분': 147, '거리': 147, '사건': 147, '공동': 147, '위치': 146, '포함': 146, '조준': 146, '히메네스': 146, '동안': 145, '이유': 145, '일부': 145, '파츠': 145, '작품': 144, '총기': 143, '교체': 143, '부상': 142, '리코': 142, '루크': 142, '직접': 141, '피해': 141, '반동': 141, '기사단': 141, '호세': 141, '판정': 140, '배우': 140, '에레': 140, '쿨타임': 139, '시메': 138, '액티브': 138, '그냥': 137, '세계': 136, '파티': 136, '습득': 136, '크게': 136, '치료': 136, '패치': 136, '다음': 135, '대비': 134, '출력': 133, '공과대학': 133, '시브': 132, '공개': 131, '전술': 131, '사카': 131, '그대로': 130, '학부': 130, '원작': 129, '브르': 129, '라운드': 128, '에피소드': 128, '테이프': 128, '콤보': 128, '국가': 127, '수비': 127, '주장': 126, '소총': 125, '사이': 124, '블랙': 124, '수도': 123, '선원': 123, '보고': 122, '장면': 122, '진행': 122, '제대로': 122, '사회': 122, '전쟁': 122, '득점': 122, '성능': 122, '던전': 122, '스토리': 121, '주인공': 121, '적용': 121, '사거리': 121, '전방': 121, '레드': 120, '역할': 120, '기도': 119, '발매': 119, '리스': 118, '이용': 118, '의미': 118, '가격': 118, '사이트': 118, '지역': 117, '치아': 117, '아키': 116, '시절': 115, '포니': 115, '핸드': 115, '바이오하자드': 114, '거나': 114, '만큼': 114, '이야기': 114, '의자': 114, '해제': 114, '제국': 114, '작화': 114, '초반': 113, '다년': 113, '서울': 113, '세르': 113, '발생': 112, '자기': 111, '스킨': 111, '이적': 111, '단계': 111, '보호': 111, '영상': 110, '방송': 110, '자주': 110, '활약': 110, '지금': 110, '유닛': 110, '주체': 109, '판타지': 108, '보이': 108, '이기': 108, '정보': 108, '운동': 108, '렉스': 108, '마찬가지': 107, '사격': 107, '포워드': 107, '제트': 107, '이반': 107, '카메': 107, '영향': 106, '패드': 106, '자리': 106, '멤버': 106, '라카': 106, '아버지': 105, '조금': 105, '출전': 105, '마누': 105, '각성': 105, '로만': 105, '체력': 105, '계열': 105, '틀레': 105, '반대': 104, '리플': 104, '개발': 104, '선발': 104, '패스트': 104, '비교': 103, '주변': 103, '아예': 103, '서브': 103, '발동': 103, '워존': 103, '최고': 102, '우리': 102, '제작': ...

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
import random
import pytagcloud
import webbrowser
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %%
count
# Out:
# Counter({'크리': 1,
#          '스핀': 1,
#          '프리': 1,
#          '김나라': 2,
#          '허수': 1,
#          '프로게이머': 1,
#          '도지': 1,
#          '코인': 1,
#          '도날드': 1,
#          '덕': 1,
#          '가족': 1,
#          '모험': 1,
#          '등장인물': 3,
#          '바이오하자드': 1,
#          '김태술': 1,
#          '페미니즘': 1,
#          '고려대학교': 1,
#          '주변': 1,
#          '상권': 1,
#          '구': 1,
#          '철': 1,
#          '십자': 1,
#          '기사단': 1,
#          '아틀레': 2,
#          '티코': 2,
#          '마드리드': 2,
#          '시즌': 3,
#          '카': 1,
#          '프록시': 1,
#          '황진성': 1,
#          '머리카락': 1,
#          '빨간색': 1,
#          '캐릭터': 1,
#          '미인': 1,
#          '눈': 1,
#          '신체': 1,
#          '파란색': 1,
#          '정미': 1,
#          '의병': 1,
#          '류진': 1,
#          '치아': 1,
#          '교정': 1,
#          '삼각형': 1,
#          '아론': 1,
#          '람스': 1,
#          '데일': 1,
#          '타': 1,
#          '코': 1,
#          '키': 1,
#          '안전': 1,
#          '신문고': 1,
#          '세계': 1,
#          '최강': 1,
#          '노력': 3,
#          '재능': 1,
#          '효율': 1,
#          '규격': 1,
#          '외': 1,
#          '용': 1,
#          '유신': 1,
#          '후지': 1,
#          '키세': 1,
#          '무스': 1,
#          '메': 2,
#          '조': 1,
#          '바이든': 1,
#          '년': 1,
#          '사우스': 1,
#          '파크': 1,
#          '국회의원': 1,
#          '루크': 1,
#          '소녀': 1,
#          '전선': 1,
#          '벨벳': 1,
#          '케이크': 1,
#          '맛': 1,
#          '쿠키': 2,
#          '쿠키런': 1,
#          '킹덤': 1,
#          '콜': 1,
#          '오브': 1,
#          '듀티': 1,
#          '블랙': 1,
#          '옵스': 1,
#          '콜드': 1,
#          '워': 1,
#          '비류': 1,
#          '무기': 1,
#          '타이탄': 1,
#          '다크': 3,
#          '스토리': 2,
#          '시리즈': 2,
#          '크리스토퍼': 1,
#          '파이크': 1,
#          '날': 1,
#          '우리': 2,
#          '집': 1,
#          '현관': 1,
#          '멸망': 1,
#          '배재대': 1,
#          '학교': 1,
#          '성우': 1,
#          '단신': 1,
#          '부활': 1,
#          '차': 1,
#          '김건': 1,
#          '부': 1,
#          '선수': 1,
#          '경력': 1,
#          '호위함대': 1,
#          '오버레이': 1,
#          '유니버스': 1,
#          '복합': 1,
#          '부위': 1,
#          '통증': 1,
#          '증후군': 1,
#          '파일': 2,
#          '건담': 2,
#          '나드레': 1,
#          '파이널': 2,
#          '판타지': 2,
#          '코로나바이러스': 1,
#          '감염증': 1,
#          '과년': 1,
#          '월': 1,
#          '레이븐': 1,
#          '엘소드': 1,
#          '레이지': 1,
#          '하츠': 1,
#          '더미': 1,
#          '버체': 1,
#          '정': 2,
#          '난의': 1,
#          '변': 1,
#          '헤일리': 1,
#          '매더스': 1,
#          '다크나이트': 1,
#          '던전': 1,
#          '앤': 1,
#          '파이터': 1,
#          '스킬': 1,
#          '분류': 1,
#          '묵향': 1,
#          '레이디': 1,
#          '나치즘': 1,
#          '리그': 2,
#          '토요일': 1,
#          '옴므': 1,
#          '손': 1,
#          '마사': 1,
#          '요시': 1,
#          '아스날': 1,
#          '가미': 1,
#          '디바이스': 1,
#          '인격': 1,
#          '에버': 1,
#          '크라이시스': 1,
#          '산타클로스': 1,
#          '서브컬쳐': 1,
#          '개성': 1,
#          '의': 1,
#          '히어로': 1,
#          '아카데미': 1,
#          '만': 1,
#          '유엔군': 1,
#          '사령부': 1,
#          '청': 1,
#          '기사': 1})

# %%
dic_count = dict(count)
dic_count['판타지']
# Out:
# 2

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')
